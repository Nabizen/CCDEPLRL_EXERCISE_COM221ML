# %% [markdown]
# <a href="https://colab.research.google.com/github/robitussin/CCDEPLRL_EXERCISES/blob/main/exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 4

# %% [markdown]
# ## Instructions
#
#
# 1. Collect **100-200 images** of the fruit
# 2. Split the collected images for train, test and validation. Please make sure that there are no duplicate images. Images that are used in train should not appear in test, validation and vice versa.
# 3. Combine the collected images together with the images of apple, orange and banana. They  are already available in the link below: https://github.com/robitussin/tensorflow_lite_projects/tree/main/images/fruits
# 4. Create and train a Convolutional Neural Network (CNN).
# 5. Save the model as **"model.tflite"**
# 6. Create a folder named **exercise_4** in your **CCDEPLRL_EXERCISES_COM222_ML** repository.
# 7. Upload the **python notebook (.ipynb)** and the **model (.tflite)** in the exercise_3 folder
#
# Deadline of submission is on **April 22, 2025**

# %% [markdown]
# ## Model

# %%
# import urllib.request

# url = "https://github.com/robitussin/tensorflow_lite_projects/blob/9f28133e4e1a8c63ed5f1c754d8972c305500878/catsanddogs.zip?raw=True"
# output_path = "animals.zip"

# urllib.request.urlretrieve(url, output_path)
# print("Download complete!")

# %%
# import zipfile
# import os

# extract_path = "animals"
# os.makedirs(extract_path, exist_ok=True)

# with zipfile.ZipFile("animals.zip", 'r') as zip_ref:
#     zip_ref.extractall(extract_path)

# print("Extraction complete!")

# %% [markdown]
# Import the libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Hyperparameters: Set the image size and batch size

# %%
img_height, img_width = 224, 224
batch_size = 32

# %% [markdown]
# Split the images into train, validation and test

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "animals/catsanddogs/train",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "animals/catsanddogs/validation",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    "animals/catsanddogs/test",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 202 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.

# %% [markdown]
# Display sample images from the dataset

# %%
class_names = ["cat", "dog"]
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
])

# %% [markdown]
# Create the Convolutional Neural Network Model (CNN)

# %%
model = tf.keras.Sequential([
    data_augmentation,
    tf.keras.layers.Rescaling(1./255),
    tf.keras.layers.Conv2D(32, 3, activation="relu"),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, 3, activation="relu"),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, 3, activation="relu"),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, 3, activation="relu"),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(2)
])

# %% [markdown]
# Define the optimizer and loss function

# %%
model.compile(
    optimizer="adam",
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits = True),
    metrics=['accuracy']
)

# %% [markdown]
# Train the model

# %%
tf.get_logger().setLevel('ERROR')
model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 50
)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 13s 478ms/step - loss: 0.7268 - accuracy: 0.5347 - val_loss: 0.6913 - val_accuracy: 0.5000
# Epoch 2/50
# 7/7 [==============================] - 2s 275ms/step - loss: 0.6991 - accuracy: 0.5000 - val_loss: 0.6909 - val_accuracy: 0.5000
# Epoch 3/50
# 7/7 [==============================] - 2s 289ms/step - loss: 0.6900 - accuracy: 0.5000 - val_loss: 0.6895 - val_accuracy: 0.5000
# Epoch 4/50
# 7/7 [==============================] - 2s 296ms/step - loss: 0.6851 - accuracy: 0.5446 - val_loss: 0.6851 - val_accuracy: 0.5200
# Epoch 5/50
# 7/7 [==============================] - 2s 297ms/step - loss: 0.6704 - accuracy: 0.6089 - val_loss: 0.6781 - val_accuracy: 0.5900
# Epoch 6/50
# 7/7 [==============================] - 2s 290ms/step - loss: 0.6541 - accuracy: 0.6535 - val_loss: 0.7584 - val_accuracy: 0.5300
# Epoch 7/50
# 7/7 [==============================] - 2s 308ms/step - loss: 0.7029 - accuracy: 0.5248 - val_loss: 0.6693 - val_accuracy: 0.5900
# Epoch 8/50
# 7/7 [==============================] - 2s 313ms/step - loss: 0.6425 - accuracy: 0.6733 - val_loss: 0.6859 - val_accuracy: 0.5400
# Epoch 9/50
# 7/7 [==============================] - 2s 294ms/step - loss: 0.6084 - accuracy: 0.7327 - val_loss: 0.6484 - val_accuracy: 0.6450
# Epoch 10/50
# 7/7 [==============================] - 2s 292ms/step - loss: 0.6355 - accuracy: 0.6485 - val_loss: 0.6711 - val_accuracy: 0.5750
# Epoch 11/50
# 7/7 [==============================] - 2s 328ms/step - loss: 0.6106 - accuracy: 0.6980 - val_loss: 0.7132 - val_accuracy: 0.5500
# Epoch 12/50
# 7/7 [==============================] - 2s 318ms/step - loss: 0.5762 - accuracy: 0.7178 - val_loss: 0.7515 - val_accuracy: 0.5600
# Epoch 13/50
# 7/7 [==============================] - 2s 285ms/step - loss: 0.5357 - accuracy: 0.7277 - val_loss: 0.6595 - val_accuracy: 0.6500
# Epoch 14/50
# 7/7 [==============================] - 2s 280ms/step - loss: 0.5252 - accuracy: 0.7376 - val_loss: 0.6858 - val_accuracy: 0.6500
# Epoch 15/50
# 7/7 [==============================] - 2s 319ms/step - loss: 0.4797 - accuracy: 0.7673 - val_loss: 0.7041 - val_accuracy: 0.6250
# Epoch 16/50
# 7/7 [==============================] - 2s 290ms/step - loss: 0.5459 - accuracy: 0.7277 - val_loss: 0.7311 - val_accuracy: 0.5600
# Epoch 17/50
# 7/7 [==============================] - 2s 310ms/step - loss: 0.5312 - accuracy: 0.7327 - val_loss: 0.6850 - val_accuracy: 0.6350
# Epoch 18/50
# 7/7 [==============================] - 2s 301ms/step - loss: 0.4519 - accuracy: 0.7871 - val_loss: 0.8409 - val_accuracy: 0.5550
# Epoch 19/50
# 7/7 [==============================] - 2s 296ms/step - loss: 0.4471 - accuracy: 0.7822 - val_loss: 0.7553 - val_accuracy: 0.6500
# Epoch 20/50
# 7/7 [==============================] - 2s 287ms/step - loss: 0.4250 - accuracy: 0.8416 - val_loss: 0.7322 - val_accuracy: 0.6400
# Epoch 21/50
# 7/7 [==============================] - 2s 301ms/step - loss: 0.3655 - accuracy: 0.8614 - val_loss: 0.9071 - val_accuracy: 0.6450
# Epoch 22/50
# 7/7 [==============================] - 2s 293ms/step - loss: 0.4604 - accuracy: 0.7772 - val_loss: 0.7903 - val_accuracy: 0.6450
# Epoch 23/50
# 7/7 [==============================] - 2s 285ms/step - loss: 0.4597 - accuracy: 0.7475 - val_loss: 0.7464 - val_accuracy: 0.6400
# Epoch 24/50
# 7/7 [==============================] - 2s 298ms/step - loss: 0.4165 - accuracy: 0.8317 - val_loss: 0.8357 - val_accuracy: 0.5950
# Epoch 25/50
# 7/7 [==============================] - 3s 353ms/step - loss: 0.4501 - accuracy: 0.7871 - val_loss: 0.6151 - val_accuracy: 0.6850
# Epoch 26/50
# 7/7 [==============================] - 3s 354ms/step - loss: 0.3820 - accuracy: 0.8515 - val_loss: 0.6681 - val_accuracy: 0.6400
# Epoch 27/50
# 7/7 [==============================] - 3s 365ms/step - loss: 0.3758 - accuracy: 0.8119 - val_loss: 0.8534 - val_accuracy: 0.6400
# Epoch 28/50
# 7/7 [==============================] - 2s 291ms/step - loss: 0.3324 - accuracy: 0.8713 - val_loss: 0.7495 - val_accuracy: 0.6500
# Epoch 29/50
# 7/7 [==============================] - 2s 298ms/step - loss: 0.3114 - accuracy: 0.8812 - val_loss: 0.7943 - val_accuracy: 0.6500
# Epoch 30/50
# 7/7 [==============================] - 2s 280ms/step - loss: 0.2845 - accuracy: 0.8812 - val_loss: 0.7934 - val_accuracy: 0.6700
# Epoch 31/50
# 7/7 [==============================] - 2s 297ms/step - loss: 0.2764 - accuracy: 0.8762 - val_loss: 0.8525 - val_accuracy: 0.6450
# Epoch 32/50
# 7/7 [==============================] - 2s 282ms/step - loss: 0.4079 - accuracy: 0.8366 - val_loss: 0.8428 - val_accuracy: 0.6400
# Epoch 33/50
# 7/7 [==============================] - 2s 296ms/step - loss: 0.3385 - accuracy: 0.8762 - val_loss: 0.8981 - val_accuracy: 0.6350
# Epoch 34/50
# 7/7 [==============================] - 2s 301ms/step - loss: 0.3338 - accuracy: 0.8812 - val_loss: 0.8094 - val_accuracy: 0.6550
# Epoch 35/50
# 7/7 [==============================] - 2s 276ms/step - loss: 0.2753 - accuracy: 0.8911 - val_loss: 0.8650 - val_accuracy: 0.6850
# Epoch 36/50
# 7/7 [==============================] - 2s 286ms/step - loss: 0.2576 - accuracy: 0.8960 - val_loss: 1.1062 - val_accuracy: 0.6200
# Epoch 37/50
# 7/7 [==============================] - 2s 287ms/step - loss: 0.2611 - accuracy: 0.8911 - val_loss: 1.0242 - val_accuracy: 0.6550
# Epoch 38/50
# 7/7 [==============================] - 2s 285ms/step - loss: 0.1611 - accuracy: 0.9356 - val_loss: 1.1302 - val_accuracy: 0.6350
# Epoch 39/50
# 7/7 [==============================] - 2s 291ms/step - loss: 0.2202 - accuracy: 0.9059 - val_loss: 1.1768 - val_accuracy: 0.6300
# Epoch 40/50
# 7/7 [==============================] - 2s 295ms/step - loss: 0.2412 - accuracy: 0.8960 - val_loss: 1.0663 - val_accuracy: 0.6750
# Epoch 41/50
# 7/7 [==============================] - 2s 306ms/step - loss: 0.1625 - accuracy: 0.9406 - val_loss: 1.1791 - val_accuracy: 0.6850
# Epoch 42/50
# 7/7 [==============================] - 2s 298ms/step - loss: 0.2077 - accuracy: 0.9010 - val_loss: 1.1138 - val_accuracy: 0.6500
# Epoch 43/50
# 7/7 [==============================] - 3s 365ms/step - loss: 0.2023 - accuracy: 0.9208 - val_loss: 1.2635 - val_accuracy: 0.6550
# Epoch 44/50
# 7/7 [==============================] - 2s 299ms/step - loss: 0.1597 - accuracy: 0.9356 - val_loss: 1.4187 - val_accuracy: 0.6400
# Epoch 45/50
# 7/7 [==============================] - 2s 305ms/step - loss: 0.1825 - accuracy: 0.9257 - val_loss: 1.2994 - val_accuracy: 0.6300
# Epoch 46/50
# 7/7 [==============================] - 2s 295ms/step - loss: 0.1402 - accuracy: 0.9505 - val_loss: 1.3413 - val_accuracy: 0.6400
# Epoch 47/50
# 7/7 [==============================] - 2s 293ms/step - loss: 0.1433 - accuracy: 0.9406 - val_loss: 1.3812 - val_accuracy: 0.6900
# Epoch 48/50
# 7/7 [==============================] - 2s 308ms/step - loss: 0.1388 - accuracy: 0.9554 - val_loss: 1.3471 - val_accuracy: 0.6850
# Epoch 49/50
# 7/7 [==============================] - 3s 370ms/step - loss: 0.0848 - accuracy: 0.9653 - val_loss: 1.3941 - val_accuracy: 0.6400
# Epoch 50/50
# 7/7 [==============================] - 2s 299ms/step - loss: 0.1003 - accuracy: 0.9653 - val_loss: 1.3764 - val_accuracy: 0.6750

# %% [markdown]
# Test the model

# %%
model.evaluate(test_ds)
# Out:
# 7/7 [==============================] - 0s 23ms/step - loss: 1.0635 - accuracy: 0.7350
# [1.063464879989624, 0.7350000143051147]

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Assume you already have: test_ds, model, class_names

plt.figure(figsize=(10, 10))

for images, labels in test_ds.take(1):
    logits = model(images, training=False)
    probs = tf.nn.softmax(logits, axis=1).numpy()
    predictions = np.argmax(probs, axis=1)
    confidences = np.max(probs, axis=1)

    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        pred_class = class_names[predictions[i]]
        true_class = class_names[int(labels[i].numpy())]
        confidence = confidences[i] * 100

        plt.title(f"Pred: {pred_class} ({confidence:.1f}%)\nReal: {true_class}")
        plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# Save the model

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open("model_animal.tflite", 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
